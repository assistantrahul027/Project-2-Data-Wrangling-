# %% [markdown]
# # Project - (Data wrangling)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew

# %%
dataset1 = pd.read_csv(r"D:\sheets.csv\dataset_1 - dataset_1.csv")        #load dataset_1
dataset1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
dataset1.head()                                      #checking first five raw
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
dataset1.tail()                                       #checking last five data
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20

# %%
dataset1.shape                                        #shape of dataset_1
# Out:
# (610, 10)

# %%
dataset1.shape[0]                                     # only number of rows
# Out:
# 610

# %%
dataset1.shape[1]                                     #only number of columns
# Out:
# 10

# %%
dataset1.describe()
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp
# count  610.000000
# mean     0.196885
# std      0.081304
# min      0.020000
# 25%      0.160000
# 50%      0.200000
# 75%      0.235000
# max      0.460000

# %%
dataset2 = pd.read_csv(r"D:\sheets.csv\dataset_2.xlsx - dataset_2.csv")
dataset2                                                                        #load the dataset_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
dataset2.head()                                                #checking first five raw
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0           0        1  0.2879  0.81        0.0       3          13   16
# 1           1        2  0.2727  0.80        0.0       8          32   40
# 2           2        3  0.2727  0.80        0.0       5          27   32
# 3           3        4  0.2879  0.75        0.0       3          10   13
# 4           4        5  0.2879  0.75        0.0       0           1    1

# %%
dataset2.tail()                                                #checking last five raw
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41

# %%
dataset1.shape
# Out:
# (610, 10)

# %%
dataset2.shape[0]
# Out:
# 610

# %%
dataset2.shape[1]
# Out:
# 8

# %%
dataset2.describe()                                       #cheacking the summary of dataset2
# Out:
#        Unnamed: 0     instant       atemp         hum   windspeed      casual  \
# count  610.000000  610.000000  599.000000  610.000000  610.000000  610.000000
# mean   304.500000  305.500000    0.199935    0.562475    0.204851    4.501639
# std    176.236111  176.236111    0.078836    0.175440    0.121806    6.319945
# min      0.000000    1.000000    0.000000    0.210000    0.000000    0.000000
# 25%    152.250000  153.250000    0.151500    0.432500    0.104500    0.000000
# 50%    304.500000  305.500000    0.197000    0.520000    0.194000    2.000000
# 75%    456.750000  457.750000    0.242400    0.690000    0.283600    6.000000
# max    609.000000  610.000000    0.454500    1.000000    0.582100   47.000000
#
#        registered         cnt
# count  610.000000  610.000000
# mean    51.068852   55.570492
# std     47.021204   49.316802
# min      0.000000    1.000000
# 25%     14.000000   16.000000
# 50%     43.000000   47.000000
# 75%     70.000000   79.750000
# ...

# %%
merged_dataset = pd.merge(dataset1, dataset2, on='instant', how='outer')
merged_dataset
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
unique_values_combined = set(dataset1 + dataset2)             #cheacking unique values from the merged dataset
unique_values_combined
# Out:
# {'Unnamed: 0',
#  'atemp',
#  'casual',
#  'cnt',
#  'dteday',
#  'holiday',
#  'hr',
#  'hum',
#  'instant',
#  'mnth',
#  'registered',
#  'season',
#  'temp',
#  'weathersit',
#  'weekday',
#  'windspeed',
#  'yr'}

# %%
merged_dataset.shape                   #shape of merged_dataset
# Out:
# (610, 17)

# %%
merged_dataset.describe()            #summary of merged_dataset
# Out:
#           instant  season     yr   mnth          hr     weekday  weathersit  \
# count  610.000000   610.0  610.0  610.0  610.000000  610.000000  610.000000
# mean   305.500000     1.0    0.0    1.0   11.795082    2.977049    1.477049
# std    176.236111     0.0    0.0    0.0    6.852107    2.054943    0.643496
# min      1.000000     1.0    0.0    1.0    0.000000    0.000000    1.000000
# 25%    153.250000     1.0    0.0    1.0    6.000000    1.000000    1.000000
# 50%    305.500000     1.0    0.0    1.0   12.000000    3.000000    1.000000
# 75%    457.750000     1.0    0.0    1.0   18.000000    5.000000    2.000000
# max    610.000000     1.0    0.0    1.0   23.000000    6.000000    4.000000
#
#              temp  Unnamed: 0       atemp         hum   windspeed      casual  \
# count  610.000000  610.000000  599.000000  610.000000  610.000000  610.000000
# mean     0.196885  304.500000    0.199935    0.562475    0.204851    4.501639
# ...

# %%
print(merged_dataset.dtypes)                # Check data types of columns in the dataset
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# Unnamed: 0      int64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
merged_dataset.isnull().sum()       #checking missing values in each column
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# Unnamed: 0     0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
merged_dataset.isnull().sum()/merged_dataset.shape[0]*100        #checking percentage of missing values in each column
# Out:
# instant       0.000000
# dteday        0.000000
# season        0.000000
# yr            0.000000
# mnth          0.000000
# hr            0.000000
# holiday       0.000000
# weekday       0.000000
# weathersit    0.000000
# temp          0.000000
# Unnamed: 0    0.000000
# atemp         1.803279
# hum           0.000000
# windspeed     0.000000
# casual        0.000000
# registered    0.000000
# cnt           0.000000
# dtype: float64

# %%
merged_dataset.fillna(0, inplace=True)                                             #fill missing values with [0]

# %%
merged_dataset.isnull().sum()                          #Treat missing values
                                                       #missing values in each column is now fill with (0)
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# Unnamed: 0    0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
merged_dataset['season'].mode()                   #Central tendency
                                                  #mode is the most frequent values
# Out:
# 0    1
# Name: season, dtype: int64

# %%
merged_dataset['season'].mean()                 #mean is the average of a data set
# Out:
# 1.0

# %%
merged_dataset['season'].median()             #Median is the middle values of dataset
# Out:
# 1.0

# %%
merged_dataset['hr'].mode()
# Out:
# 0    12
# 1    13
# 2    14
# 3    15
# 4    16
# 5    17
# Name: hr, dtype: int64

# %%
merged_dataset['hr'].mean()
# Out:
# 11.795081967213115

# %%
merged_dataset['hr'].median()
# Out:
# 12.0

# %%
merged_dataset['atemp'].mode()
# Out:
# 0    0.197
# Name: atemp, dtype: float64

# %%
merged_dataset['atemp'].mean()
# Out:
# 0.1963295081967213

# %%
merged_dataset['atemp'].median()
# Out:
# 0.197

# %%
dataset3 = pd.read_csv(r"D:\sheets.csv\dataset_3 - dataset_3.csv")      #loading the dataset3
dataset3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
dataset3.head()                         #first five raw of datasset3
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0      620  29-01-2011       1   0     1   1    False        6           1
# 1      621  29-01-2011       1   0     1   2    False        6           1
# 2      622  29-01-2011       1   0     1   3    False        6           1
# 3      623  29-01-2011       1   0     1   4    False        6           1
# 4      624  29-01-2011       1   0     1   6    False        6           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.22  0.2273  0.64     0.1940       0          20   20
# 1  0.22  0.2273  0.64     0.1642       0          15   15
# 2  0.20  0.2121  0.64     0.1343       3           5    8
# 3  0.16  0.1818  0.69     0.1045       1           2    3
# 4  0.16  0.1818  0.64     0.1343       0           2    2

# %%
dataset3.tail()                         #last five raw of datasset3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 385  0.24  0.2273  0.70     0.1940       1          61   62
# 386  0.22  0.2273  0.75     0.1343       1          57   58
# 387  0.24  0.2121  0.65     0.3582       0          26   26
# 388  0.24  0.2273  0.60     0.2239       1          22   23
# 389  0.22  0.1970  0.64     0.3582       2          26   28

# %%
dataset3.shape
# Out:
# (390, 16)

# %%
dataset3.describe()                    #cheacking the summary of dataset3
# Out:
#            instant  season     yr        mnth          hr     weekday  \
# count   390.000000   390.0  390.0  390.000000  390.000000  390.000000
# mean    805.500000     1.0    0.0    1.800000   11.687179    2.989744
# std     112.727548     0.0    0.0    0.400514    6.980295    2.149884
# min     611.000000     1.0    0.0    1.000000    0.000000    0.000000
# 25%     708.250000     1.0    0.0    2.000000    6.000000    1.000000
# 50%     805.500000     1.0    0.0    2.000000   12.000000    3.000000
# 75%     902.750000     1.0    0.0    2.000000   18.000000    5.000000
# max    1000.000000     1.0    0.0    2.000000   23.000000    6.000000
#
#        weathersit        temp       atemp         hum   windspeed      casual  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean     1.484615    0.220000    0.230424    0.613769    0.179416    5.576923
# std      0.663805    0.073095    0.069455    0.202361    0.138551    9.317478
# ...

# %%
#Quick overview of the Dataset3's structure, including the number of rows, columns, 
#non-null counts, and data types of each column.
dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    object
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), float64(4), int64(10), object(1)
# memory usage: 46.2+ KB

# %%
#cheack the datatype of dataset3
print(dataset3.dtypes)
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# #Concatenate combine_ data with Dataset_3

# %%
combined_dataset = pd.concat([merged_dataset, dataset3], axis=0, ignore_index=True)

combined_dataset                              #Concatinate mered_dataset with dataset3Co
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 995      615  28-01-2011       1   0     1  20    False        5           2
# 996      616  28-01-2011       1   0     1  21    False        5           2
# 997      617  28-01-2011       1   0     1  22    False        5           1
# 998      618  28-01-2011       1   0     1  23    False        5           1
# 999      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
combined_dataset.shape                      #checking shaoe if new combined dataset
# Out:
# (1000, 17)

# %%
combined_dataset.head()                    #cheacking first five raw of new Combined dataset
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp  Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24         0.0  0.2879  0.81        0.0       3          13   16
# 1  0.22         1.0  0.2727  0.80        0.0       8          32   40
# 2  0.22         2.0  0.2727  0.80        0.0       5          27   32
# 3  0.24         3.0  0.2879  0.75        0.0       3          10   13
# 4  0.24         4.0  0.2879  0.75        0.0       0           1    1

# %%
combined_dataset.tail()                     #cheacking last five raws of new combined dataset
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 995      615  28-01-2011       1   0     1  20    False        5           2
# 996      616  28-01-2011       1   0     1  21    False        5           2
# 997      617  28-01-2011       1   0     1  22    False        5           1
# 998      618  28-01-2011       1   0     1  23    False        5           1
# 999      619  29-01-2011       1   0     1   0    False        6           1
#
#      temp  Unnamed: 0   atemp   hum  windspeed  casual  registered  cnt
# 995  0.24         NaN  0.2273  0.70     0.1940       1          61   62
# 996  0.22         NaN  0.2273  0.75     0.1343       1          57   58
# 997  0.24         NaN  0.2121  0.65     0.3582       0          26   26
# 998  0.24         NaN  0.2273  0.60     0.2239       1          22   23
# 999  0.22         NaN  0.1970  0.64     0.3582       2          26   28

# %%
print(combined_dataset.dtypes)               #cheack the datatype of new combined dataset
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday          bool
# weekday         int64
# weathersit      int64
# temp          float64
# Unnamed: 0    float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
combined_dataset.isnull().sum()                #wokring on missing values of combined_dataset
                                               # combined_dataset of merged data of dataset1, 2, 3
                                               #checking missing values
# Out:
# instant         0
# dteday          0
# season          0
# yr              0
# mnth            0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# temp            0
# Unnamed: 0    390
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# dtype: int64

# %%
combined_dataset.isnull().sum()/combined_dataset.shape[0]*100    #cheacking missing values by percentage
# Out:
# instant        0.0
# dteday         0.0
# season         0.0
# yr             0.0
# mnth           0.0
# hr             0.0
# holiday        0.0
# weekday        0.0
# weathersit     0.0
# temp           0.0
# Unnamed: 0    39.0
# atemp          0.0
# hum            0.0
# windspeed      0.0
# casual         0.0
# registered     0.0
# cnt            0.0
# dtype: float64

# %%
combined_dataset.fillna(0, inplace=True)               #fill mising values wirth [0]
                                                        #treat missing values of dataset

# %%
combined_dataset.isnull().sum()                       #missing values in each column is now fill with (0)
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# Unnamed: 0    0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
combined_dataset.isnull().sum()/combined_dataset.shape[0]*100      #missing values in each column is now fill with 0 
                                                                   #percentage wise
# Out:
# instant       0.0
# dteday        0.0
# season        0.0
# yr            0.0
# mnth          0.0
# hr            0.0
# holiday       0.0
# weekday       0.0
# weathersit    0.0
# temp          0.0
# Unnamed: 0    0.0
# atemp         0.0
# hum           0.0
# windspeed     0.0
# casual        0.0
# registered    0.0
# cnt           0.0
# dtype: float64

# %%
sns.boxplot(x= 'hr', data=combined_dataset)       #checking outliers of Combined_dataset
plt.title('Boxplot of Values')                    # Add title and labels
plt.xlabel('Values')                             
plt.show()

# %%
sns.boxplot(x= 'cnt', data=combined_dataset)     #checking outliers of Combined_dataset
plt.title('Boxplot of Values')                   # Add title and labels

plt.xlabel('Values')                                         
plt.show()

# %%
Q1 = np.percentile(combined_dataset['cnt'], 25, method='midpoint')              # Calculating percentiles and IQR
Q3 = np.percentile(combined_dataset['cnt'], 75, method='midpoint')
IQR = Q3 - Q1
print(IQR)
# Out:
# 67.0

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR                   # Define outlier boundaries


# Identify outliers

outliers = combined_dataset[(combined_dataset['cnt'] < lower_bound) | (combined_dataset['cnt'] > upper_bound)]
print(outliers)
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 85        86  04-01-2011       1   0     1  17    False        2           1
# 99       100  05-01-2011       1   0     1   8    False        3           1
# 108      109  05-01-2011       1   0     1  17    False        3           1
# 122      123  06-01-2011       1   0     1   8    False        4           1
# 145      146  07-01-2011       1   0     1   8    False        5           1
# 154      155  07-01-2011       1   0     1  17    False        5           2
# 217      218  10-01-2011       1   0     1   8    False        1           2
# 239      240  11-01-2011       1   0     1   8    False        2           2
# 285      286  13-01-2011       1   0     1   8    False        4           1
# 415      416  19-01-2011       1   0     1   8    False        3           2
# 424      425  19-01-2011       1   0     1  17    False        3           1
# ...

# %% [markdown]
# # skewness of the combined_dataset

# %%
skewness_scipy = skew(combined_dataset['cnt'])       # Calculate skewness using scipy for purticular cols
print(skewness_scipy)                                #combined_dataset
# Out:
# 1.1360018484482277

# %%
skewness_scipy = skew(combined_dataset['instant'])       # Calculate skewness of another cols using scipy 
print(skewness_scipy)                                    #combined_dataset
# Out:
# 0.0

# %%
skewness_scipy = skew(combined_dataset['windspeed'])       # Calculate skewness of another cols using scipy  
print(skewness_scipy)                                      #combined_dataset
# Out:
# 0.43302427863828036

# %%
skewness_scipy = skew(combined_dataset['registered'])       # Calculate skewness of another cols using scipy  
print(skewness_scipy)                                       #combined_dataset
# Out:
# 1.2947774086609287

# %%
numeric_data = combined_dataset.select_dtypes(include='number')   # Compute skewness for each numeric column
                                                                  #Combined_dataset
skewness = numeric_data.skew()

print(skewness)
print("Skewness of each numeric column:")
# Out:
# instant       0.000000
# season        0.000000
# yr            0.000000
# mnth          0.812772
# hr           -0.063524
# weekday       0.021925
# weathersit    1.044098
# temp          0.547997
# Unnamed: 0    0.635299
# atemp         0.260339
# hum           0.436893
# windspeed     0.433675
# casual        3.414105
# registered    1.296723
# cnt           1.137709
# dtype: float64
# Skewness of each numeric column:

# %%
numeric_data.hist(figsize=(12, 10), bins=30)              # Plot histograms for numeric columns

plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
# Calculate correlation matrix
correlation_matrix = combined_dataset.corr(numeric_only=True)

print(correlation_matrix)
# Out:
#              instant  season  yr      mnth        hr   holiday   weekday  \
# instant     1.000000     NaN NaN  0.802477  0.000060 -0.063013  0.008157
# season           NaN     NaN NaN       NaN       NaN       NaN       NaN
# yr               NaN     NaN NaN       NaN       NaN       NaN       NaN
# mnth        0.802477     NaN NaN  1.000000 -0.025646 -0.105600  0.034710
# hr          0.000060     NaN NaN -0.025646  1.000000 -0.005753  0.007531
# holiday    -0.063013     NaN NaN -0.105600 -0.005753  1.000000 -0.148682
# weekday     0.008157     NaN NaN  0.034710  0.007531 -0.148682  1.000000
# weathersit  0.030439     NaN NaN  0.014061 -0.055802  0.165443  0.060007
# temp        0.023406     NaN NaN  0.159660  0.203512 -0.059728 -0.081776
# Unnamed: 0 -0.296155     NaN NaN -0.617946  0.018959  0.153200  0.005879
# atemp       0.118692     NaN NaN  0.203293  0.142770 -0.064903 -0.037799
# hum         0.062116     NaN NaN  0.066587 -0.194853 -0.037542  0.062469
# ...

# %%
plt.figure(figsize=(10, 8))             # Plot heatmap of the correlation matrix using matplotlib lib.

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)

plt.title('Correlation Heatmap')
plt.show()
